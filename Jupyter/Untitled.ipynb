# %%
List = ['abc']

# %%
List[0]='123'
print(List)
# Out:
# ['123']

# %%
Dict={}
Dict[0]=1
Dict[110]=2

# %%
print(Dict[0])
# Out:
# 1

# %%
print(Dict.ElementAt(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5z/jy1hh51j44z9633q501drhp40000gn/T/ipykernel_54858/1641740776.py in <module>
# ----> 1 print(Dict.ElementAt(0))
#
# AttributeError: 'dict' object has no attribute 'ElementAt'
